# %% [markdown]
# # Title Goes Here

# %% [markdown]
# ### Python Requirements

# %%
from sklearn import svm
SVC = svm.SVC()
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os.path
from IPython.display import HTML

# %% [markdown]
# ## Data generation code

# %% [markdown]
# ## NOTE: this is referencing a specific notebook !!! I might need to change this in the future to use the right code.

# %%
# %run 'Project_hackathon_clean_yuriy3.ipynb'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/justingosses/Code/Hackathon_Agile/hackathon2017/Project_hackathon_clean_yuriy3.ipynb in <module>()
# ----> 1 answer = testUnseenEvents(events2Model,events3_testEvents)
#
# NameError: name 'events2Model' is not defined

# %%
# Generate points
events=points_gen(2,2,2)

# Convert generated points to data (t(x))
data, labels, x = points_to_data(events)

# Convert data to seismic
seism = data_to_seism(data, x)

# Plot
bob = data_plot(seism,data,labels,x,'yes')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-fb013b4b765b> in <module>()
#       1 # Generate points
# ----> 2 events=points_gen(2,2,2)
#       3
#       4 # Convert generated points to data (t(x))
#       5 data, labels, x = points_to_data(events)
#
# TypeError: points_gen() missing 1 required positional argument: 'nMU'

# %%
def getBothDataSets(input1,input2,input3,input4):
    # generate points for training
    eventsA = points_gen(200,200,200,200)
    # Convert generated points A to data (t(x))
    data, labels, x = points_to_data(eventsA)
    # generate points for testing
    eventsB = points_gen(200,200,200,200)
    # Convert generated points A to data (t(x))
    dataB, labelsB, xB = points_to_data(eventsB)
    # make a model from training data
    model = comboFunctionA(eventsA)
    # generate predicted labels for B based on model from A
    newLabels = predict_from_data(eventsB, model)
    
    # Convert data to seismic
    seism = data_to_seism(data, x)
    # Convert data to seismic
    seismB = data_to_seism(dataB, xB)

    dataA = data_plot(data,labels,x,'no')
    dataBLabels = data_plot(data,labels,x,'yes')
    dataB = data_plot(data,newLabels,x,'yes')
    
    fig = bob.get_figure()
    fig.savefig("output.png", bbox_inches='tight', pad_inches=0)

# %%
# generate points for training
events2 = points_gen(200,200,200,200)

# make a model from training data
model = comboFunctionA(events2)

newLabels = predict_from_data(events, model)

data_plot(data,labels,x,'no')
data_plot(data,labels,x,'yes')
data_plot(data,newLabels,x,'yes')

# %%
fig = bob.get_figure()
fig.savefig("output.png", bbox_inches='tight', pad_inches=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0de94e3486ae> in <module>()
# ----> 1 fig = bob.get_figure()
#       2 fig.savefig("output.png", bbox_inches='tight', pad_inches=0)
#
# NameError: name 'bob' is not defined

# %%
def bigPythonFunction(input1,input2,input3,input4):
    print("bigPythonFunction works, it returns = ",input1,input2,input3,input4)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-e4d9de76cb45> in <module>()
# ----> 1 testPythonCode = bigPythonFunction(input1,input2,input3,input4)
#
# NameError: name 'input1' is not defined

# %% [markdown]
# ### Load HTML/CSS/JavaScript requirements

# %%
# %%javascript
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min'
#   }
# });

# %%
# %%javascript
# require.config({
#   paths: {
#       bootstrapCSS: '//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css'
#   }
# });

# %%
# %%javascript
# require.config({
#   paths: {
#       bootstrap: '//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js'
#   }
# });

# %% [markdown]
# ## User Interface

# %% [markdown]
# Eventually, this might be moved to a normal HTML/CSS/JS webpage outside of a jupyter notebook that is accessible like any other webpage and either talks to a server to run the models or if want to get really fancy (and more secure) does everything including applying the model in the browser by porting the python code to JavaScript via web assembly. For now though, we're just running it in the jupyter notebook.

# %% [markdown]
# #### HTML, CSS, and JavaScript code for User Interface

# %%
from IPython.display import display


def on_button_clicked(b):
    print("Button clicked.")

# %%
input_form = """
<style>
 body {
    background-color: lightblue;
}
div#title{
    text-align:center;
    margin-top: 40px;
    margin-bottom: 40px;
    hieght: 150px;
}
div#parameters {
    height: 100px;
    text-align: center;
}
h2#parameters {
    height: 50px; 
}
img{
    padding-left:50px;
}
</style>
<div id="title">
    <h1>Seismic Shotgather Record Colorizer</h1>
</div>
<div id="parameters" style="height:100px;">
    <h2>Parameters</h2>
    <div>
         direct: <input type="text" id="direct" value="10">
         reflections: <input type="text" id="reflections" value="8">
         multiples: <input type="text" id="multiples" value="7">
         Coherent Noise: <input type="text" id="coherentNoise" value="6"><br>
         <button onclick="set_value()">Generate images & Train Model</button>
         <button onclick="set_value()">Use Model to label right image</button>
    </div>
</div>
<div">
</div>
<div class="col-md-4 marginL">
    <h4>Labeled Data A</h4>
    <p>Came with labels, which are colored.</p>
    <p>Labels used to generate SVM ML model.</p>
    <img src="output.png" alt="gathers" align="middle">
    <div>
        <button onclick="set_value()">Export image used in training</button>
    </div>
</div>
<div class="col-md-4 marginL">
    <h4>Unlabled Data B</h4>
    <p>Labels (colors) not original but found using model</p>
    <p>Model came from example to left</p>
    <img src="output.png" alt="gathers" align="middle">
    <div>
        <button onclick="set_value()">Export image now colorized by SVM model</button>
    </div>
</div>
<div class="col-md-4 marginL">
    <h4>Labled Data B</h4>
    <p>Labels (colors) are original </p>
    <p>from this dataset</p>
    <img src="output.png" alt="gathers" align="middle">
    <div>
        <button onclick="set_value()">Export image with original labels</button>
    </div>
</div>
<p id="tester">test</p>
"""

javascript = """
<script type="text/Javascript">
    function set_value(){
        console.log("test the console workss");
        var direct = document.getElementById('direct').value;
        var reflections = document.getElementById('reflections').value;
        var multiples = document.getElementById('multiples').value;
        var coherentNoise = document.getElementById('coherentNoise').value;
        console.log("test the console workss");
        var_value = "testheretest"
        var command = var_name + " = '" + var_value + "'";
        var command1 = var_dir + " = '"+ direct +"'";
        var command0 = var_dir + " = " + direct + ", " + var_refl + " = " + reflections+ ", " + var_mult + " = " + multiples + ", "+ var_Noise + " = " + coherentNoise + ";
        var command3 = var_dir + " = '" + var_value + "'";
        var command4 = var_dir + " = '" + 4 + "'";
        var command2 = 'bigPythonFunction("+direct+reflections+multiples+coherentNoise+")'
        var commandOrig = direct + " = '" + direct + "'";
        console.log("test the console works: command is ",command);
        var kernel = IPython.notebook.kernel;
        kernel.execute(command);
    }
</script>
""" 
# def testPythonCode():
#     bigPythonFunction(direct,reflections,multiples,coherentNoise)
# % testPythonCode

# var command = 'bigPythonFunction("+direct+reflections+multiples+coherentNoise+")'


HTML(input_form + javascript)
# Out:
# <style>
#  body {
#     background-color: lightblue;
# }
# div#title{
#     text-align:center;
#     margin-top: 40px;
#     margin-bottom: 40px;
#     hieght: 150px;
# }
# div#parameters {
#     height: 100px;
#     text-align: center;
# }
# h2#parameters {
#     height: 50px;
# }
# img{
#     padding-left:50px;
# }
# </style>
# <div id="title">
#     <h1>Seismic Shotgather Record Colorizer</h1>
# </div>
# <div id="parameters" style="height:100px;">
#     <h2>Parameters</h2>
#     <div>
#          direct: <input type="text" id="direct" value="10">
#          reflections: <input type="text" id="reflections" value="8">
#          multiples: <input type="text" id="multiples" value="7">
#          Coherent Noise: <input type="text" id="coherentNoise" value="6"><br>
#          <button onclick="set_value()">Generate images & Train Model</button>
#          <button onclick="set_value()">Use Model to label right image</button>
#     </div>
# </div>
# <div">
# </div>
# <div class="col-md-4 marginL">
#     <h4>Labeled Data A</h4>
#     <p>Came with labels, which are colored.</p>
#     <p>Labels used to generate SVM ML model.</p>
#     <img src="output.png" alt="gathers" align="middle">
#     <div>
#         <button onclick="set_value()">Export image used in training</button>
#     </div>
# </div>
# <div class="col-md-4 marginL">
#     <h4>Unlabled Data B</h4>
#     <p>Labels (colors) not original but found using model</p>
#     <p>Model came from example to left</p>
#     <img src="output.png" alt="gathers" align="middle">
#     <div>
#         <button onclick="set_value()">Export image now colorized by SVM model</button>
#     </div>
# </div>
# <div class="col-md-4 marginL">
#     <h4>Labled Data B</h4>
#     <p>Labels (colors) are original </p>
#     <p>from this dataset</p>
#     <img src="output.png" alt="gathers" align="middle">
#     <div>
#         <button onclick="set_value()">Export image with original labels</button>
#     </div>
# </div>
# <p id="tester">test</p>
#
# <script type="text/Javascript">
#     function set_value(){
#         console.log("test the console workss");
#         var direct = document.getElementById('direct').value;
#         var reflections = document.getElementById('reflections').value;
#         var multiples = document.getElementById('multiples').value;
#         var coherentNoise = document.getElementById('coherentNoise').value;
#         console.log("test the console workss");
#         var_value = "testheretest"
#         var command = var_name + " = '" + var_value + "'";
#         var command1 = var_dir + " = '"+ direct +"'";
#         var command0 = var_dir + " = " + direct + ", " + var_refl + " = " + reflections+ ", " + var_mult + " = " + multiples + ", "+ var_Noise + " = " + coherentNoise + ";
#         var command3 = var_dir + " = '" + var_value + "'";
#         var command4 = var_dir + " = '" + 4 + "'";
#         var command2 = 'bigPythonFunction("+direct+reflections+multiples+coherentNoise+")'
#         var commandOrig = direct + " = '" + direct + "'";
#         console.log("test the console works: command is ",command);
#         var kernel = IPython.notebook.kernel;
#         kernel.execute(command);
#     }
# </script>

# %%
input_form = """
<style>
 body {
    background-color: lightblue;
}
div#title{
    text-align:center;
    margin-top: 40px;
    margin-bottom: 40px;
    hieght: 150px;
}
div#parameters {
    height: 100px;
    text-align: center;
}
h2#parameters {
    height: 50px; 
}
img{
    padding-left:50px;
}
</style>
<div id="title">
    <h1>Seismic Shotgather Record Colorizer</h1>
</div>
<div id="parameters" style="height:100px;">
    <h2>Parameters</h2>
    <div>
         direct: <input type="text" id="direct" value="10">
         reflections: <input type="text" id="reflections" value="8">
         multiples: <input type="text" id="multiples" value="7">
         Coherent Noise: <input type="text" id="coherentNoise" value="6"><br>
         <button onclick="set_value()">Generate images & Train Model</button>
         <button onclick="set_value()">Use Model to label right image</button>
    </div>
</div>
<div">
</div>
<div class="col-md-4 marginL">
    <h4>Labeled Data A</h4>
    <p>Came with labels, which are colored.</p>
    <p>Labels used to generate SVM ML model.</p>
    <img src="output.png" alt="gathers" align="middle">
    <div>
        <button onclick="set_value()">Export image used in training</button>
    </div>
</div>
<div class="col-md-4 marginL">
    <h4>Unlabled Data B</h4>
    <p>Labels (colors) not original but found using model</p>
    <p>Model came from example to left</p>
    <img src="output.png" alt="gathers" align="middle">
    <div>
        <button onclick="set_value()">Export image now colorized by SVM model</button>
    </div>
</div>
<div class="col-md-4 marginL">
    <h4>Labled Data B</h4>
    <p>Labels (colors) are original </p>
    <p>from this dataset</p>
    <img src="output.png" alt="gathers" align="middle">
    <div>
        <button onclick="set_value()">Export image with original labels</button>
    </div>
</div>
<p id="tester">test</p>
"""

javascript = """
<script type="text/Javascript">
    function set_value(){
        console.log("test the console workss");
        var direct = document.getElementById('direct').value;
        var reflections = document.getElementById('reflections').value;
        var multiples = document.getElementById('multiples').value;
        var coherentNoise = document.getElementById('coherentNoise').value;
        console.log("test the console workss");
        var_value = "testheretest"
        var command = var_name + " = '" + var_value + "'";
        var command1 = var_dir + " = '"+ direct +"'";
        var command0 = var_dir + " = " + direct + ", " + var_refl + " = " + reflections+ ", " + var_mult + " = " + multiples + ", "+ var_Noise + " = " + coherentNoise + ";
        var command3 = var_dir + " = '" + var_value + "'";
        var command4 = var_dir + " = '" + 4 + "'";
        var command2 = 'bigPythonFunction("+direct+reflections+multiples+coherentNoise+")'
        var commandOrig = direct + " = '" + direct + "'";
        console.log("test the console works: command is ",command);
        var kernel = IPython.notebook.kernel;
        kernel.execute(command);
    }
</script>
""" 
# def testPythonCode():
#     bigPythonFunction(direct,reflections,multiples,coherentNoise)
# % testPythonCode

# var command = 'bigPythonFunction("+direct+reflections+multiples+coherentNoise+")'


HTML(input_form + javascript)

# %%
button = widgets.Button(description="Click Me!")
display(button)
# button.on_click(on_button_clicked)
# button.on_click(bigPythonFunction(direct,reflections,multiples,coherentNoise))
button.on_click(print(var_name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-2c93a2fe3505> in <module>()
#       3 # button.on_click(on_button_clicked)
#       4 # button.on_click(bigPythonFunction(direct,reflections,multiples,coherentNoise))
# ----> 5 button.on_click(print(var_name))
#
# NameError: name 'var_name' is not defined

# %%
input_form = """
<div style="background-color:gainsboro; border:solid black; width:300px; padding:20px;">
Variable Name: <input type="text" id="var_name" value="foo"><br>
Variable Value: <input type="text" id="var_value" value="bar"><br>
<button onclick="set_value()">Set Value</button>
</div>
"""

javascript = """
<script type="text/Javascript">
    function set_value(){
        var var_name = document.getElementById('var_name').value;
        var var_value = document.getElementById('var_value').value;
        var command = var_name + " = '" + var_value + "'";
        console.log("Executing Command: ",command);
        
        var kernel = IPython.notebook.kernel;
        kernel.execute(command);
    }
</script>
"""

HTML(input_form + javascript)
# Out:
# <div style="background-color:gainsboro; border:solid black; width:300px; padding:20px;">
# Variable Name: <input type="text" id="var_name" value="foo"><br>
# Variable Value: <input type="text" id="var_value" value="bar"><br>
# <button onclick="set_value()">Set Value</button>
# </div>
#
# <script type="text/Javascript">
#     function set_value(){
#         var var_name = document.getElementById('var_name').value;
#         var var_value = document.getElementById('var_value').value;
#         var command = var_name + " = '" + var_value + "'";
#         console.log("Executing Command: ",command);
#
#         var kernel = IPython.notebook.kernel;
#         kernel.execute(command);
#     }
# </script>

# %%
print(foo)
# Out:
# bar234

# %%
import ipywidgets as widgets

# %%
def f(x):
    print(x)

interact(f, x=1,widgets.Button(
    
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check'
))
# Out:
#   File "<ipython-input-53-4a005d2d2384>", line 4
#     interact(f, x=1,widgets.Button(
#                    ^
# SyntaxError: positional argument follows keyword argument

# %%
import ipywidgets as widgets
print(widgets.Button.on_click.__doc__)
# Out:
# Register a callback to execute when the button is clicked.
#
#         The callback will be called with one argument,
#         the clicked button widget instance.
#
#         Parameters
#         ----------
#         remove : bool (optional)
#             Set to true to remove the callback from the list of callbacks.

# %%
widgets.Button(
    
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check'
)

# %%
from IPython.display import display
button = widgets.Button(description="Click Me!")
display(button)

def on_button_clicked(b):
    print("Button clicked.")

button.on_click(on_button_clicked)
# Out:
# Button clicked.
# Button clicked.
# Button clicked.
